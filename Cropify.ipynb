# %%
import numpy as np

# %%
import matplotlib.pyplot as plt #imread(),imshow()

# %%
#fruits
# !gdown 17tYTDPBU5hpby9t0kGd7w_-zBsbY7sEd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17tYTDPBU5hpby9t0kGd7w_-zBsbY7sEd
# To: /content/fruits.png
# 100% 4.71M/4.71M [00:00<00:00, 23.3MB/s]

# %%
#emma stone
# !gdown 1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# To: /content/emma_stone.jpeg
# 100% 80.3k/80.3k [00:00<00:00, 110MB/s]

# %%
img=plt.imread("fruits.png")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#color dimensions are always in 3d.black and white are 2d 
img.ndim

# %%
img.shape
# Out:
# (1333, 2000, 3)

# %%
 plt.imshow(img)

# %%
#transpose image or rotate image
plt.imshow(np.transpose(img,(1,0,2)))

# %%
#copy
img_r=img.copy()
img_r[:,:,[1,2]]=0 #turn green and blue value to zero so that we can see red
plt.imshow(img_r)

# %%
img_r=img.copy()
img_r[:,:,[0,1]]=0 #turn red and green value to zero so that we can see blue
plt.imshow(img_r)

# %%
#Brighter the intensity more colour is used
#Darker the intensity less colour is used

# %%
#CROPPING

# %%
img=plt.imread("emma_stone.jpeg")

# %%
plt.imshow(img) #shape may be (H,W,3)---> (600,900,3)

# %%
img.shape
# Out:
# (600, 900, 3)

# %%
plt.imshow(img[0:450,250:700,:])
